# %% [markdown]
# The given tutorial gives a brief introduction on how time series dataset can be with Convolutional Neural Network architechture for developing a simple CNN classifier.
# (API Reference: https://www.sktime.net/en/stable/api_reference/auto_generated/sktime.classification.deep_learning.CNNClassifier.html)

# %%
#Install Dependencies and SkTime
# !pip install tensorflow
# !pip install sktime[dl]
# !pip install sktime[all_extras]
# Out:
# Requirement already satisfied: tensorflow in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.65.4)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.6.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.24.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.6)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (8.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.18.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Requirement already satisfied: sktime[dl] in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (0.34.0)
# Requirement already satisfied: joblib<1.5,>=1.2.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (1.4.2)
# Requirement already satisfied: numpy<2.2,>=1.21 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (1.24.2)
# Requirement already satisfied: packaging in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (24.1)
# Requirement already satisfied: pandas<2.3.0,>=1.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (2.2.2)
# Requirement already satisfied: scikit-base<0.12.0,>=0.6.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (0.11.0)
# Requirement already satisfied: scikit-learn<1.6.0,>=0.24 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (1.11.2)
# Requirement already satisfied: neuralforecast<1.8.0,>=1.6.4 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (1.7.5)
# Requirement already satisfied: FrEIA in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (0.2)
# Requirement already satisfied: peft>=0.10.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (0.13.2)
# Requirement already satisfied: tensorflow<2.17,>=2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (2.16.1)
# Requirement already satisfied: torch in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (2.3.0+cu121)
# Requirement already satisfied: transformers<4.41.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from transformers[torch]<4.41.0; python_version < "3.12" and extra == "dl"->sktime[dl]) (4.31.0)
# Requirement already satisfied: lightning>=2.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (2.4.0)
# Requirement already satisfied: gluonts>=0.14.3 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (0.15.1)
# Requirement already satisfied: einops>0.7.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (0.8.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (0.24.5)
# Requirement already satisfied: pytorch-forecasting<1.2.0,>=1.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (1.1.1)
# Requirement already satisfied: hydra-core in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[dl]) (1.3.2)
# Requirement already satisfied: pydantic<3,>=1.7 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from gluonts>=0.14.3->sktime[dl]) (2.8.2)
# Requirement already satisfied: tqdm~=4.23 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from gluonts>=0.14.3->sktime[dl]) (4.64.1)
# Requirement already satisfied: toolz~=0.10 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from gluonts>=0.14.3->sktime[dl]) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from gluonts>=0.14.3->sktime[dl]) (4.9.0)
# Requirement already satisfied: filelock in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from huggingface-hub>=0.23.0->sktime[dl]) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from huggingface-hub>=0.23.0->sktime[dl]) (2024.2.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from huggingface-hub>=0.23.0->sktime[dl]) (6.0.1)
# Requirement already satisfied: requests in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from huggingface-hub>=0.23.0->sktime[dl]) (2.31.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from lightning>=2.0->sktime[dl]) (0.11.8)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from lightning>=2.0->sktime[dl]) (1.5.1)
# Requirement already satisfied: pytorch-lightning in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from lightning>=2.0->sktime[dl]) (2.4.0)
# Requirement already satisfied: coreforecast>=0.0.6 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (0.0.14)
# Requirement already satisfied: ray>=2.2.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from ray[tune]>=2.2.0->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (2.6.1)
# Requirement already satisfied: optuna in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (4.0.0)
# Requirement already satisfied: utilsforecast>=0.0.25 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (0.2.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pandas<2.3.0,>=1.1->sktime[dl]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pandas<2.3.0,>=1.1->sktime[dl]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pandas<2.3.0,>=1.1->sktime[dl]) (2024.1)
# Requirement already satisfied: psutil in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from peft>=0.10.0->sktime[dl]) (6.0.0)
# Requirement already satisfied: accelerate>=0.21.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from peft>=0.10.0->sktime[dl]) (0.33.0)
# Requirement already satisfied: safetensors in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from peft>=0.10.0->sktime[dl]) (0.4.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from scikit-learn<1.6.0,>=0.24->sktime[dl]) (3.5.0)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow<2.17,>=2->sktime[dl]) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (4.25.5)
# Requirement already satisfied: setuptools in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (1.65.4)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (3.6.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (0.31.0)
# Requirement already satisfied: sympy in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from torch->sktime[dl]) (1.12)
# Requirement already satisfied: networkx in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from torch->sktime[dl]) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from torch->sktime[dl]) (3.1.3)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from torch->sktime[dl]) (2021.4.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from transformers<4.41.0->transformers[torch]<4.41.0; python_version < "3.12" and extra == "dl"->sktime[dl]) (2024.7.24)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from transformers<4.41.0->transformers[torch]<4.41.0; python_version < "3.12" and extra == "dl"->sktime[dl]) (0.13.3)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from hydra-core->sktime[dl]) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from hydra-core->sktime[dl]) (4.9.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->sktime[dl]) (3.10.2)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->sktime[dl]) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->sktime[dl]) (2021.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pydantic<3,>=1.7->gluonts>=0.14.3->sktime[dl]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pydantic<3,>=1.7->gluonts>=0.14.3->sktime[dl]) (2.20.1)
# Requirement already satisfied: click>=7.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (8.1.7)
# Requirement already satisfied: jsonschema in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (1.0.8)
# Requirement already satisfied: aiosignal in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (1.3.1)
# Requirement already satisfied: frozenlist in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (1.4.1)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from ray[tune]>=2.2.0->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (2.6.2.2)
# Collecting pyarrow<7.0.0,>=6.0.1 (from ray[tune]>=2.2.0->neuralforecast<1.8.0,>=1.6.4->sktime[dl])
#   Using cached pyarrow-6.0.1-cp39-cp39-win_amd64.whl.metadata (2.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from requests->huggingface-hub>=0.23.0->sktime[dl]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from requests->huggingface-hub>=0.23.0->sktime[dl]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from requests->huggingface-hub>=0.23.0->sktime[dl]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from requests->huggingface-hub>=0.23.0->sktime[dl]) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tqdm~=4.23->gluonts>=0.14.3->sktime[dl]) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from jinja2->torch->sktime[dl]) (2.1.5)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from optuna->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (1.14.0)
# Requirement already satisfied: colorlog in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from optuna->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from optuna->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (2.0.36)
# Requirement already satisfied: mpmath>=0.19 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sympy->torch->sktime[dl]) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->sktime[dl]) (2.3.5)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->sktime[dl]) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->sktime[dl]) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->sktime[dl]) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->sktime[dl]) (4.0.3)
# Requirement already satisfied: Mako in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from alembic>=1.5.0->optuna->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (1.3.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (0.43.0)
# Requirement already satisfied: rich in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (13.7.1)
# Requirement already satisfied: namex in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (0.0.8)
# Requirement already satisfied: optree in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (0.13.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sqlalchemy>=1.3.0->optuna->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (3.1.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (3.0.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast<1.8.0,>=1.6.4->sktime[dl]) (0.20.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (8.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (2.18.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[dl]) (0.1.2)
# Using cached pyarrow-6.0.1-cp39-cp39-win_amd64.whl (15.5 MB)
# Installing collected packages: pyarrow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.0.0
#     Uninstalling pyarrow-18.0.0:
#       Successfully uninstalled pyarrow-18.0.0
# Successfully installed pyarrow-6.0.1
# Requirement already satisfied: sktime[all_extras] in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (0.34.0)
# Requirement already satisfied: joblib<1.5,>=1.2.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (1.4.2)
# Requirement already satisfied: numpy<2.2,>=1.21 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (1.24.2)
# Requirement already satisfied: packaging in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (24.1)
# Requirement already satisfied: pandas<2.3.0,>=1.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (2.2.2)
# Requirement already satisfied: scikit-base<0.12.0,>=0.6.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.11.0)
# Requirement already satisfied: scikit-learn<1.6.0,>=0.24 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (1.11.2)
# Requirement already satisfied: autots<0.7,>=0.6.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.6.15)
# Requirement already satisfied: skpro<2.8.0,>=2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (2.7.0)
# Requirement already satisfied: esig==0.9.7 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.9.7)
# Requirement already satisfied: filterpy>=1.4.5 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (1.4.5)
# Requirement already satisfied: hmmlearn>=0.2.7 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.3.3)
# Requirement already satisfied: keras-self-attention in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.51.0)
# Requirement already satisfied: pyod>=0.8 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (2.0.2)
# Requirement already satisfied: stumpy>=1.5.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (1.13.0)
# Requirement already satisfied: tslearn!=0.6.0,<0.7.0,>=0.5.2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.6.3)
# Requirement already satisfied: h5py in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (3.12.1)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (2.0.4)
# Requirement already satisfied: prophet>=1.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (1.1.6)
# Requirement already satisfied: pyts<0.14.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.13.0)
# Requirement already satisfied: statsforecast<1.8.0,>=1.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (1.7.8)
# Requirement already satisfied: tbats>=1.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (1.1.3)
# Requirement already satisfied: tensorflow<2.17,>=2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (2.16.1)
# Requirement already satisfied: tsfresh>=0.17 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.20.3)
# Requirement already satisfied: arch<7.1.0,>=5.6 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (7.0.0)
# Requirement already satisfied: cloudpickle in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (3.1.0)
# Requirement already satisfied: dash!=2.9.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (2.18.2)
# Requirement already satisfied: dtaidistance<2.4 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (2.3.12)
# Requirement already satisfied: dtw-python in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (1.5.3)
# Requirement already satisfied: gluonts>=0.9 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.15.1)
# Requirement already satisfied: holidays in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.60)
# Requirement already satisfied: matplotlib!=3.9.1,>=3.3.2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (3.9.2)
# Requirement already satisfied: mne in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (1.8.0)
# Requirement already satisfied: numba<0.61,>=0.53 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.60.0)
# Requirement already satisfied: optuna<4.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (4.0.0)
# Requirement already satisfied: polars<2.0,>=0.20 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from polars[pandas]<2.0,>=0.20; python_version < "3.13" and extra == "all_extras"->sktime[all_extras]) (1.12.0)
# Requirement already satisfied: pycatch22<0.4.6 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.4.5)
# Requirement already satisfied: scikit-optimize in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.10.2)
# Requirement already satisfied: scikit-posthocs>=0.6.5 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.10.0)
# Requirement already satisfied: seaborn>=0.11 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.13.2)
# Requirement already satisfied: seasonal in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.3.1)
# Requirement already satisfied: skforecast<0.14,>=0.12.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.13.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.14.4)
# Requirement already satisfied: u8darts<0.32.0,>=0.29.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (0.31.0)
# Requirement already satisfied: xarray in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sktime[all_extras]) (2024.7.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (5.24.1)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (8.2.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (4.9.0)
# Requirement already satisfied: requests in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (2.31.0)
# Requirement already satisfied: retrying in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from dash!=2.9.0->sktime[all_extras]) (71.0.4)
# Requirement already satisfied: pydantic<3,>=1.7 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from gluonts>=0.9->sktime[all_extras]) (2.8.2)
# Requirement already satisfied: tqdm~=4.23 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from gluonts>=0.9->sktime[all_extras]) (4.64.1)
# Requirement already satisfied: toolz~=0.10 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from gluonts>=0.9->sktime[all_extras]) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from matplotlib!=3.9.1,>=3.3.2->sktime[all_extras]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from matplotlib!=3.9.1,>=3.3.2->sktime[all_extras]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from matplotlib!=3.9.1,>=3.3.2->sktime[all_extras]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from matplotlib!=3.9.1,>=3.3.2->sktime[all_extras]) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from matplotlib!=3.9.1,>=3.3.2->sktime[all_extras]) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from matplotlib!=3.9.1,>=3.3.2->sktime[all_extras]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from matplotlib!=3.9.1,>=3.3.2->sktime[all_extras]) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from matplotlib!=3.9.1,>=3.3.2->sktime[all_extras]) (6.4.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from numba<0.61,>=0.53->sktime[all_extras]) (0.43.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from optuna<4.1->sktime[all_extras]) (1.14.0)
# Requirement already satisfied: colorlog in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from optuna<4.1->sktime[all_extras]) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from optuna<4.1->sktime[all_extras]) (2.0.36)
# Requirement already satisfied: PyYAML in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from optuna<4.1->sktime[all_extras]) (6.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pandas<2.3.0,>=1.1->sktime[all_extras]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pandas<2.3.0,>=1.1->sktime[all_extras]) (2024.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8->sktime[all_extras]) (3.0.10)
# Requirement already satisfied: urllib3 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8->sktime[all_extras]) (2.2.2)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from prophet>=1.1->sktime[all_extras]) (1.2.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from scikit-learn<1.6.0,>=0.24->sktime[all_extras]) (3.5.0)
# Requirement already satisfied: coreforecast>=0.0.12 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.0.14)
# Requirement already satisfied: fugue>=0.8.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.9.1)
# Requirement already satisfied: utilsforecast>=0.1.4 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.2.8)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from statsmodels>=0.12.1->sktime[all_extras]) (0.5.6)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (4.25.5)
# Requirement already satisfied: six>=1.12.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (1.65.4)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (3.6.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (0.31.0)
# Requirement already satisfied: nfoursid>=1.0.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from u8darts<0.32.0,>=0.29.0->sktime[all_extras]) (1.0.1)
# Requirement already satisfied: shap>=0.40.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from u8darts<0.32.0,>=0.29.0->sktime[all_extras]) (0.46.0)
# Requirement already satisfied: xgboost>=1.6.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from u8darts<0.32.0,>=0.29.0->sktime[all_extras]) (2.1.2)
# Requirement already satisfied: decorator in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from mne->sktime[all_extras]) (5.1.1)
# Requirement already satisfied: jinja2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from mne->sktime[all_extras]) (3.1.3)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from mne->sktime[all_extras]) (0.4)
# Requirement already satisfied: pooch>=1.5 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from mne->sktime[all_extras]) (1.8.2)
# Requirement already satisfied: pyaml>=16.9 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from scikit-optimize->sktime[all_extras]) (24.9.0)
# Requirement already satisfied: Mako in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from alembic>=1.5.0->optuna<4.1->sktime[all_extras]) (1.3.6)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from cmdstanpy>=1.0.4->prophet>=1.1->sktime[all_extras]) (0.5.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from Flask<3.1,>=1.0.4->dash!=2.9.0->sktime[all_extras]) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from Flask<3.1,>=1.0.4->dash!=2.9.0->sktime[all_extras]) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from Flask<3.1,>=1.0.4->dash!=2.9.0->sktime[all_extras]) (1.8.2)
# Requirement already satisfied: triad>=0.9.7 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.9.8)
# Requirement already satisfied: adagio>=0.2.4 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.2.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from importlib-metadata->dash!=2.9.0->sktime[all_extras]) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from jinja2->mne->sktime[all_extras]) (2.1.5)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from plotly>=5.0.0->dash!=2.9.0->sktime[all_extras]) (9.0.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pooch>=1.5->mne->sktime[all_extras]) (4.2.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pydantic<3,>=1.7->gluonts>=0.9->sktime[all_extras]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from pydantic<3,>=1.7->gluonts>=0.9->sktime[all_extras]) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from requests->dash!=2.9.0->sktime[all_extras]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from requests->dash!=2.9.0->sktime[all_extras]) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from requests->dash!=2.9.0->sktime[all_extras]) (2024.7.4)
# Requirement already satisfied: slicer==0.0.8 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from shap>=0.40.0->u8darts<0.32.0,>=0.29.0->sktime[all_extras]) (0.0.8)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from sqlalchemy>=1.3.0->optuna<4.1->sktime[all_extras]) (3.1.1)
# Requirement already satisfied: colorama in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tqdm~=4.23->gluonts>=0.9->sktime[all_extras]) (0.4.6)
# Collecting pyarrow>=7.0.0 (from polars<2.0,>=0.20->polars[pandas]<2.0,>=0.20; python_version < "3.13" and extra == "all_extras"->sktime[all_extras])
#   Using cached pyarrow-18.0.0-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (0.43.0)
# Requirement already satisfied: rich in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (13.7.1)
# Requirement already satisfied: namex in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (0.0.8)
# Requirement already satisfied: optree in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (0.13.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (0.7.2)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (2024.2.0)
# Requirement already satisfied: fs in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (2.4.16)
# Requirement already satisfied: appdirs~=1.4.3 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from fs->triad>=0.9.7->fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (1.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shrey\anaconda3\envs\mmpose\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2->sktime[all_extras]) (0.1.2)
# Using cached pyarrow-18.0.0-cp39-cp39-win_amd64.whl (25.1 MB)
# Installing collected packages: pyarrow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 6.0.1
#     Uninstalling pyarrow-6.0.1:
#       Successfully uninstalled pyarrow-6.0.1
# Successfully installed pyarrow-18.0.0

# %%
#Import sktime
import sktime
#Import classifier to be used
from sktime.classification.deep_learning.cnn import CNNClassifier
#Import datasets currently available in sktime
from sktime.datasets import load_basic_motions

# %%
# load an example time series panel in pd-multiindex mtype
X, Y = load_basic_motions(return_type="pd-multiindex")

# renaming columns for illustrative purposes
X.columns = ["accel_1", "accel_2", "accel_3", "gyro_1", "gyro_2", "gyro_3"]
X.index.names = ["trial_no", "timepoint"]

# %% [markdown]
# The basic motions dataset has:
#
# - 80 individual time series instances = trials = person engaging in an activity like running, badminton, etc.
# - Six variables per time series instance, dim_0 to dim_5 (renamed according to the values they represent)
# - 3 accelerometer and 3 gyrometer measurements (Multi-variate dataset)
# - Individual time series are observed at 100 time points (the same number for all instances)

# %%
# The outermost index represents the instance number
# whereas the inner index represents the index of the particular index
# within that instance.
X
# Out:
#                       accel_1    accel_2   accel_3    gyro_1    gyro_2  \
# trial_no timepoint
# 0        0           0.079106   0.394032  0.551444  0.351565  0.023970
#          1           0.079106   0.394032  0.551444  0.351565  0.023970
#          2          -0.903497  -3.666397 -0.282844 -0.095881 -0.319605
#          3           1.116125  -0.656101  0.333118  1.624657 -0.569962
#          4           1.638200   1.405135  0.393875  1.187864 -0.271664
# ...                       ...        ...       ...       ...       ...
# 79       95         28.459024 -16.633770  3.631869  8.978229 -3.611533
#          96         10.260094   0.102775  1.269261 -1.645964 -3.377157
#          97          4.316471  -3.574319  2.063831 -1.717875 -1.843054
#          98          0.704446  -4.920444  2.851857 -2.982977 -0.809665
#          99         -2.074749  -6.892377  4.848379 -1.350330 -1.203844
#
#                       gyro_3
# trial_no timepoint
# 0        0          0.633883
#          1          0.633883
#          2          0.972131
#          3          1.209171
#          4          1.739182
# ...                      ...
# 79       95        -1.491489
#          96         1.283746
#          97         0.484734
#          98        -0.721774
#          99        -1.776470
#
# [8000 rows x 6 columns]

# %%
# Check the labels for each X value
Y
# Out:
# array(['standing', 'standing', 'standing', 'standing', 'standing',
#        'standing', 'standing', 'standing', 'standing', 'standing',
#        'running', 'running', 'running', 'running', 'running', 'running',
#        'running', 'running', 'running', 'running', 'walking', 'walking',
#        'walking', 'walking', 'walking', 'walking', 'walking', 'walking',
#        'walking', 'walking', 'badminton', 'badminton', 'badminton',
#        'badminton', 'badminton', 'badminton', 'badminton', 'badminton',
#        'badminton', 'badminton', 'standing', 'standing', 'standing',
#        'standing', 'standing', 'standing', 'standing', 'standing',
#        'standing', 'standing', 'running', 'running', 'running', 'running',
#        'running', 'running', 'running', 'running', 'running', 'running',
#        'walking', 'walking', 'walking', 'walking', 'walking', 'walking',
#        'walking', 'walking', 'walking', 'walking', 'badminton',
#        'badminton', 'badminton', 'badminton', 'badminton', 'badminton',
#        'badminton', 'badminton', 'badminton', 'badminton'], dtype='<U9')

# %%
# Check length of labels
Y.shape
# Out:
# (80,)

# %%
# Select:
# * the fourth variable (gyroscope 1)
# * of the twentieth instance (trial 20 in python)
# * values at all 100 timestamps
X.loc[20, "gyro_1"]
# Out:
# timepoint
# 0    -1.033389
# 1    -1.033389
# 2     0.066584
# 3     0.599259
# 4     0.663180
#         ...
# 95    0.210406
# 96    0.870923
# 97    0.870923
# 98    1.600687
# 99   -0.170456
# Name: gyro_1, Length: 100, dtype: float64

# %%
# Select:
# * the 1st variable (accelerometer 1)
# * of the 79th instance (trial 79 in python)
# * the 98th time point
X.loc[(79, 98), "accel_1"]
# Out:
# 0.704446

# %%
# Splitting the same file into training and testing set
X_train, y_train = load_basic_motions(split="train", return_type="numpy3D")
X_test, y_test = load_basic_motions(split="test", return_type="numpy3D")

# %%
# Sanity check to find training features and truth labels
print(X_train.shape)
print(y_train.shape)
# Out:
# (40, 6, 100)
# (40,)

# %%
#Import CNN classifier
from sktime.classification.deep_learning.cnn import CNNClassifier

# %%
#Define the CNN classifier
cnn = CNNClassifier(n_epochs=20,batch_size=4)
cnn.fit(X_train, y_train)
# Out:
# CNNClassifier(batch_size=4, n_epochs=20)

# %%
# nested parameter interface via get_params, set_params
cnn.get_params()
# Out:
# {'activation': 'softmax',
#  'avg_pool_size': 3,
#  'batch_size': 4,
#  'callbacks': None,
#  'filter_sizes': None,
#  'kernel_size': 7,
#  'loss': 'categorical_crossentropy',
#  'metrics': None,
#  'n_conv_layers': 2,
#  'n_epochs': 20,
#  'optimizer': None,
#  'padding': 'auto',
#  'random_state': None,
#  'use_bias': True,
#  'verbose': False}

# %%
# We inspect fitted parameters if we like
cnn.get_fitted_params()
# Out:
# {'classes': array(['badminton', 'running', 'standing', 'walking'], dtype='<U9'),
#  'fit_time': 2235,
#  'model': <Functional name=functional_7, built=True>,
#  'n_classes': 4,
#  'optimizer': <keras.src.optimizers.adam.Adam at 0x21c2214ceb0>}

# %%
#Store the predictions from CNN over testing set
y_pred = cnn.predict(X_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Evaluate the results
from sklearn.metrics import classification_report

# %%
#Print evaluation metrics
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#    badminton       1.00      0.80      0.89        10
#      running       1.00      1.00      1.00        10
#     standing       0.91      1.00      0.95        10
#      walking       0.82      0.90      0.86        10
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.92      0.92        40
# weighted avg       0.93      0.93      0.92        40

# %% [markdown]
# Try the same with Multi-Layered Perceptron..
# API Reference: https://www.sktime.net/en/stable/api_reference/auto_generated/sktime.classification.deep_learning.MLPClassifier.html
